# %%
from manim import *

class SecretSquare(Scene):
    def construct(self):
        square = Square(color=BLUE).rotate(PI/4)
        self.play(Create(square))
        self.wait()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from manim import *
#       3 class SecretSquare(Scene):
#       4     def construct(self):
#
# ModuleNotFoundError: No module named 'manim'
