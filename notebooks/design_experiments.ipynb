# %%
! uv pip install manim
# Out:
# Using Python 3.12.2 environment at: /Users/soheilsanati/Downloads/Alpha-Carina-Research-Laboratory/aCarina
# Resolved 35 packages in 678ms
#    Building pycairo==1.29.0
#    Building pycairo==1.29.0
#    Building pycairo==1.29.0
# ⠹ Preparing packages... (0/3)
#    Building pycairo==1.29.0------------     0 B/19.92 MiB
# ⠹ Preparing packages... (0/3)
#    Building pycairo==1.29.0------------     0 B/19.92 MiB
# ⠹ Preparing packages... (0/3)
# av                   ------------------------------     0 B/18.57 MiB
#    Building pycairo==1.29.0------------     0 B/19.92 MiB
# ⠹ Preparing packages... (0/3)
# av                   ------------------------------ 16.00 KiB/18.57 MiB
#    Building pycairo==1.29.0------------     0 B/19.92 MiB
# ⠹ Preparing packages... (0/3)
# av                   ------------------------------ 32.00 KiB/18.57 MiB
#    Building pycairo==1.29.0------------     0 B/19.92 MiB
# ⠹ Preparing packages... (0/3)
# ...
