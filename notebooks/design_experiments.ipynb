# %%
! pip install manim
# Out:
# ...
#   Using cached manim-0.19.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached av-13.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.4 kB)
# ...
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached cloup-3.0.8-py2.py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached isosurfaces-0.1.2-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached manimpango-0.6.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.2 kB)
# ...
#   Using cached mapbox_earcut-2.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.5 kB)
# ...
#   Using cached moderngl_window-3.1.1-py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached moderngl-5.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.8 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached numpy-2.4.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached pillow-12.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
